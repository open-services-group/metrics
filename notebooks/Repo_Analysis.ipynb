# %% [markdown]
# # GitHub Repository Metric Analysis
#
# In this notebook, we will fetch the GitHub Issue/PR data for the repositories mentioned in [sigs.yaml](https://github.com/open-services-group/community/blob/main/sigs.yaml) using the [MI tool](https://github.com/thoth-station/mi), pre-process the raw data into suitable data frames and store them as parquet files to an s3 bucket. We will also create [Trino](https://trino.io/) tables for the generated parquet files so that we can later create dashboards in [Superset](https://superset.operate-first.cloud/).
#
# This notebook will serve as a template notebook to analyze different GitHub repositories so that it can be easily executed in automation as part of our metrics processing pipeline. The notebook can be executed in parallel for different repos by passing as an argument the GitHub repository for which we would like to analyze and calculate metrics.
#
# (Related issues: [Issue 1](https://github.com/open-services-group/metrics/issues/19))

# %%
import os
import yaml
import requests
from dotenv import find_dotenv, load_dotenv
import warnings
import trino
from s3_communication import S3Communication
from github import Github
import pandas as pd

warnings.filterwarnings("ignore")
load_dotenv(find_dotenv())
# Out:
# True

# %%
## Create a .env file on your local with the correct configs
RAW_SIGS_YAML_URL = os.getenv("RAW_SIGS_YAML_URL")
GITHUB_ACCESS_TOKEN = os.getenv("GITHUB_ACCESS_TOKEN")

s3_bucket = os.getenv("S3_BUCKET")
s3_endpoint_url = os.getenv("S3_ENDPOINT")
aws_access_key_id = os.getenv("S3_ACCESS_KEY")
aws_secret_access_key = os.getenv("S3_SECRET_KEY")

# %%
# Note: The GitHub access token needs to be exported before importing the srcopmetrics package (current bug)
from srcopsmetrics.entities.issue import Issue  # noqa: E402
from srcopsmetrics.entities.pull_request import PullRequest  # noqa: E402

# %%
# init s3 connector
s3c = S3Communication(
    s3_endpoint_url, aws_access_key_id, aws_secret_access_key, s3_bucket
)

# %%
# read the sigs.yaml file
ret = requests.get(RAW_SIGS_YAML_URL)
sigs_file = yaml.load(ret.content)

# %%
def get_org_repo_from_owners_slug(owners_slug):
    split_path = owners_slug.split("/")
    org = split_path[3]
    repo = split_path[4]
    return org, repo

# %%
# Remove any existing old data
# !rm -r srcopsmetrics/

# Gather the data for each subproject in sig (other groups may not have a repo
# associated with them)
# NOTE: there are cases where multiple subprojects have the same repo
# In such cases, we dont wanna pull the github data all over again since
# we're already constrained by the amount of github API calls we can make
# So this set keeps track of repos for which data is already pulled, and
# makes sure API calls arent made for a repo for which data already exists
repos_collected = set()

for sig in sigs_file['sigs']:
    for sp in sig['subprojects']:
        for owners_slug in sp['owners']:
            org, repo = get_org_repo_from_owners_slug(owners_slug)
            if owners_slug not in repos_collected:
                print(f'#### Collecting data for {org}/{repo}')
                # !python -m srcopsmetrics.cli -clr $org/$repo -e Issue,PullRequest # noqa: E999
                repos_collected.add(owners_slug)
# Out:
# #### Collecting data for open-services-group/community
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing open-services-group/community ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for open-services-group/community with 85 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|████████████████████| 158/158 [00:16<00:00,  9.73it/s, RATE remaining=4907]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for open-services-group/community with 73 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #142
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #139
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #132
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #124
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #121
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #120
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #119
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #118
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #116
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #114
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #105
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #104
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #103
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #102
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #101
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #100
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #95
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #94
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #90
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #86
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #84
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #83
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #82
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #80
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #70
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #68
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #67
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #57
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #55
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #54
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #52
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #51
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #50
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #49
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #48
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #46
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #45
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #44
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #43
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #42
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #41
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #40
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #39
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #37
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #36
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #34
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #33
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #30
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #28
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #25
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #24
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #23
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #21
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #20
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #19
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #18
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #13
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #12
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #11
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #10
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #7
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #5
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# 100%|██████████████████████| 73/73 [00:05<00:00, 14.23it/s, RATE remaining=4902]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for open-services-group/metrics
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing open-services-group/metrics ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for open-services-group/metrics with 21 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 34/34 [00:03<00:00,  9.00it/s, RATE remaining=4877]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for open-services-group/metrics with 13 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #34
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #33
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #32
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #28
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #26
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #25
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #20
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #12
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #11
# 100%|██████████████████████| 13/13 [00:01<00:00, 11.76it/s, RATE remaining=4874]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for os-climate/aicoe-osc-demo
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing os-climate/aicoe-osc-demo ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for os-climate/aicoe-osc-demo with 85 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|████████████████████| 150/150 [00:16<00:00,  9.25it/s, RATE remaining=4781]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for os-climate/aicoe-osc-demo with 65 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #148
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #147
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #144
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #143
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #140
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #139
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #138
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #137
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #136
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #133
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #130
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #129
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #126
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #124
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #123
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #119
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #117
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #116
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #114
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #112
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #108
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #107
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #104
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #103
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #101
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #98
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #89
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #86
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #85
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #83
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #82
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #81
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #77
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #76
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #75
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #74
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #73
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #71
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #70
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #67
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #66
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #65
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #64
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #63
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #62
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #55
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #53
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #50
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #47
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #46
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #42
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #41
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #37
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #36
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #35
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #34
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #33
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #30
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #21
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #1
# 100%|██████████████████████| 65/65 [00:05<00:00, 11.83it/s, RATE remaining=4777]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for os-climate/data-platform-demo
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing os-climate/data-platform-demo ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for os-climate/data-platform-demo with 36 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 49/49 [00:06<00:00,  8.11it/s, RATE remaining=4737]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for os-climate/data-platform-demo with 13 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #41
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #39
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #38
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #23
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #22
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #20
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #13
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #11
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #10
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #7
# 100%|██████████████████████| 13/13 [00:01<00:00, 13.00it/s, RATE remaining=4734]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for os-climate/osc-ingest-tools
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing os-climate/osc-ingest-tools ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for os-climate/osc-ingest-tools with 2 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 29/29 [00:04<00:00,  6.12it/s, RATE remaining=4707]
# INFO:srcopsmetrics.entities.interface:Knowledge file Issue.json
# INFO:srcopsmetrics.entities.interface:new 8 entities
# INFO:srcopsmetrics.entities.interface:(overall 10 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/os-climate/osc-ingest-tools/Issue.json
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #28
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #25
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #24
# ERROR:srcopsmetrics.entities.tools.knowledge:Size label not found
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #22
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #20
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #18
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #12
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #5
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #3
# 100%|██████████████████████| 19/19 [00:24<00:00,  1.28s/it, RATE remaining=4540]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 19 entities
# INFO:srcopsmetrics.entities.interface:(overall 19 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/os-climate/osc-ingest-tools/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for os-climate/osc-trino-acl-dsl
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing os-climate/osc-trino-acl-dsl ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous Issue knowledge for os-climate/osc-trino-acl-dsl with 4 records
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|████████████████████████| 8/8 [00:00<00:00,  9.08it/s, RATE remaining=4524]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for os-climate/osc-trino-acl-dsl with 4 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #5
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# 100%|████████████████████████| 4/4 [00:00<00:00,  9.00it/s, RATE remaining=4521]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for aicoe-aiops/operate-first-data-science-community
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing aicoe-aiops/operate-first-data-science-community ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/aicoe-aiops/operate-first-data-science-community
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type Issue found
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 90/90 [00:23<00:00,  3.77it/s, RATE remaining=4362]
# INFO:srcopsmetrics.entities.interface:Knowledge file Issue.json
# INFO:srcopsmetrics.entities.interface:new 50 entities
# INFO:srcopsmetrics.entities.interface:(overall 50 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/aicoe-aiops/operate-first-data-science-community/Issue.json
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #90
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #88
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #86
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #80
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #79
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #78
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #77
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #74
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #71
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #70
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #68
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #66
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #65
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #64
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #63
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #62
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #61
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #60
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #59
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/5
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/5
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/5
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/5
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/5
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #53
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #48
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #44
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #43
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #39
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/19
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #33
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #24
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #22
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/7
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #13
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #11
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #1
# 100%|██████████████████████| 40/40 [00:57<00:00,  1.44s/it, RATE remaining=4009]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 40 entities
# INFO:srcopsmetrics.entities.interface:(overall 40 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/aicoe-aiops/operate-first-data-science-community/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for open-services-group/peribolos-as-a-service
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing open-services-group/peribolos-as-a-service ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/open-services-group/peribolos-as-a-service
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type Issue found
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 75/75 [00:20<00:00,  3.64it/s, RATE remaining=3841]
# INFO:srcopsmetrics.entities.interface:Knowledge file Issue.json
# INFO:srcopsmetrics.entities.interface:new 51 entities
# INFO:srcopsmetrics.entities.interface:(overall 51 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/open-services-group/peribolos-as-a-service/Issue.json
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #75
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #50
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #49
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #48
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #45
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #44
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #43
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #42
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #41
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #40
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #28
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #25
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 22/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 23/23
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #20
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #18
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #13
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #1
# 100%|██████████████████████| 24/24 [00:38<00:00,  1.60s/it, RATE remaining=3633]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 24 entities
# INFO:srcopsmetrics.entities.interface:(overall 24 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/open-services-group/peribolos-as-a-service/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:
#
# #### Collecting data for AICoE/seraph
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing AICoE/seraph ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/AICoE/seraph
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type Issue found
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 27/27 [00:07<00:00,  3.41it/s, RATE remaining=3577]
# INFO:srcopsmetrics.entities.interface:Knowledge file Issue.json
# INFO:srcopsmetrics.entities.interface:new 15 entities
# INFO:srcopsmetrics.entities.interface:(overall 15 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/AICoE/seraph/Issue.json
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #25
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #22
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #13
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #12
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# 100%|██████████████████████| 12/12 [00:17<00:00,  1.47s/it, RATE remaining=3475]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 12 entities
# INFO:srcopsmetrics.entities.interface:(overall 12 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/AICoE/seraph/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:

# %% [markdown]
# ## Issue Metrics
#
# Now, lets fetch the issues for the repository and derive some metrics.

# %%
def get_issue_metrics(sig, org, repo):
    # read repo data we fetched in previous step via MI
    issue = Issue(f"{org}/{repo}")
    issue_df = issue.load_previous_knowledge(is_local=True)
    issue_df = issue_df.reset_index()

    # Retain only relevant columns
    issue_cols_to_drop = ["labels", "interactions"]
    issue_df = issue_df.drop(columns=issue_cols_to_drop)

    # add sig, org, repo columns
    issue_df["sig"] = sig
    issue_df["org"] = org
    issue_df["repo"] = repo

    return issue_df

# %%
# lets read a sample df
issue_df = get_issue_metrics(
    sig="sig-data-science", org="os-climate", repo="aicoe-osc-demo"
)
issue_df.head()
# Out:
#     id                                     title  \
# 0  150        Run infer_relevance.ipynb in demo2
# 1  149                   Deliver Container Image
# 2  146                   Deliver Container Image
# 3  145  Remove editable src package from pipfile
# 4  142             Fine tune KPI inference model
#
#                                                 body       created_by  \
# 0  I have an issue when I run this notebook. Ther...     JeremyGohBNP
# 1  Hey, AICoE-CI!\r\n\r\nPlease build and deliver...       Shreyanand
# 2  Hey, AICoE-CI!\r\n\r\nPlease build and deliver...       Shreyanand
# 3  Remove editable _src_ package from the Pipfile...       Shreyanand
# 4  As a data scientist,\r\nI want to fine tune a ...  chauhankaranraj
#
#            created_at closed_by           closed_at               sig  \
# 0 2022-04-21 09:43:13      None                 NaT  sig-data-science
# 1 2022-04-14 15:14:43   sesheta 2022-04-14 15:44:21  sig-data-science
# 2 2022-04-13 15:19:00   sesheta 2022-04-13 15:50:35  sig-data-science
# 3 2022-04-11 14:10:53      None                 NaT  sig-data-science
# 4 2022-04-04 19:35:17      None                 NaT  sig-data-science
#
#           org            repo
# 0  os-climate  aicoe-osc-demo
# 1  os-climate  aicoe-osc-demo
# 2  os-climate  aicoe-osc-demo
# 3  os-climate  aicoe-osc-demo
# 4  os-climate  aicoe-osc-demo

# %%
# read in and process issue dfs for all repos
# then upload the processed df to s3 as a parquet file
for sig in sigs_file["sigs"]:
    for sp in sig["subprojects"]:
        for owners_slug in sp["owners"]:
            # parse org, repo names
            org, repo = get_org_repo_from_owners_slug(owners_slug)

            # create issues df for org, repo
            issue_df = get_issue_metrics(sig=sig["dir"], org=org, repo=repo)

            # upload to bucket
            s3c.upload_df_to_s3(
                df=issue_df,
                s3_prefix="open-services-group/metrics/github/issues",
                s3_key=f"{org}-{repo}.parquet",
            )

# %% [markdown]
# ## PR Metrics
#
# Now, lets fetch the PRs for the repository and derive some metrics.

# %%
def get_pr_metrics(sig, org, repo):
    # read repo data we fetched in previous step via MI
    pr = PullRequest(f"{org}/{repo}")
    pr_df = pr.load_previous_knowledge(is_local=True)
    pr_df = pr_df.reset_index()

    # Retain only relevant columns
    pr_cols_to_drop = ["interactions", "reviews", "labels", "commits", "changed_files"]
    prs_df = pr_df.drop(columns=pr_cols_to_drop)

    # add sigs,org,repo
    prs_df["sig"] = sig
    prs_df["org"] = org
    prs_df["repo"] = repo

    return prs_df

# %%
pr_df = get_pr_metrics(sig="sig-data-science", org="os-climate", repo="aicoe-osc-demo")
pr_df.head()
# Out:
#     id                                              title  \
# 0  148  Update table curator to work w changes in kpi ...
# 1  147  Downgrade markupsafe to fix soft_unicode depre...
# 2  144                     Remove s3c from kpi-mapping.py
# 3  143  Update base image version in Dockerfile. Updat...
# 4  140                           Step 2.5 Fine Tune model
#
#                                                 body size       created_by  \
# 0  pdf text curation notebook imports curation cl...    S  chauhankaranraj
# 1             Fixes os-climate/os_c_data_commons#162   XL  chauhankaranraj
# 2  Closes #69 \r\n\r\nThis PR makes following cha...  XXL       Shreyanand
# 3  Update image so that it works in the new Elyra...  XXL  chauhankaranraj
# 4  Signed-off-by: Francesco Murdaca <fmurdaca@red...  XXL        pacospace
#
#            created_at           closed_at        closed_by  \
# 0 2022-04-14 14:27:32 2022-04-14 14:30:01       Shreyanand
# 1 2022-04-14 14:07:34 2022-04-14 14:25:54       Shreyanand
# 2 2022-04-08 19:13:26 2022-04-13 14:59:49  chauhankaranraj
# 3 2022-04-05 18:10:23 2022-04-05 19:00:15  MichaelClifford
# 4 2022-03-16 10:50:53                 NaT             None
#
#             merged_at        merged_by  commits_number  changed_files_number  \
# 0 2022-04-14 14:30:01       Shreyanand               1                     1
# 1 2022-04-14 14:25:54       Shreyanand               1                     2
# 2 2022-04-13 14:59:49  chauhankaranraj               1                    15
# 3 2022-04-05 19:00:15  MichaelClifford               1                     2
# 4                 NaT             None               2                     3
#
#       first_review_at    first_approve_at               sig         org  \
# 0 2022-04-14 14:29:15 2022-04-14 14:29:15  sig-data-science  os-climate
# 1 2022-04-14 14:09:22                 NaT  sig-data-science  os-climate
# 2 2022-04-11 20:20:52 2022-04-13 14:53:50  sig-data-science  os-climate
# 3                 NaT                 NaT  sig-data-science  os-climate
# 4                 NaT                 NaT  sig-data-science  os-climate
#
#              repo
# 0  aicoe-osc-demo
# 1  aicoe-osc-demo
# 2  aicoe-osc-demo
# 3  aicoe-osc-demo
# 4  aicoe-osc-demo

# %%
# read in and process pr dfs for all repos
# then upload the processed df to s3 as a parquet file
for sig in sigs_file["sigs"]:
    for sp in sig["subprojects"]:
        for owners_slug in sp["owners"]:
            # parse org, repo names
            org, repo = get_org_repo_from_owners_slug(owners_slug)

            # create prs df for org, repo
            pr_df = get_pr_metrics(sig=sig["dir"], org=org, repo=repo)

            # upload to bucket
            s3c.upload_df_to_s3(
                df=pr_df,
                s3_prefix="open-services-group/metrics/github/prs",
                s3_key=f"{org}-{repo}.parquet",
            )

# %% [markdown]
# ## Contributors metrics
# Next, lets fetch the events for the repository. This table will be used to find information about contributors, their affiliations and the events they generate in the repository.

# %%
# To do
# In the current version we can only get data for the last 90 days or 300 events
# limited by the guithub API
# Add a loop for getting older data
# Probably, get all events for a month and then loop to the next month

# %%
def get_events_df(sig, org, repo):
    ## Get internal members of OSG group
    gth_obj = Github(GITHUB_ACCESS_TOKEN)
    osg = gth_obj.get_organization("open-services-group")
    internal = [m.login for m in osg.get_members()]

    gh_repo_obj = gth_obj.get_repo(f"{org}/{repo}")

    # Define events we are interested in
    issue_event_types = ["IssueCommentEvent", "IssuesEvent"]

    pr_event_types = [
        "PullRequestEvent",
        "PullRequestReviewEvent",
        "PullRequestReviewCommentEvent",
    ]

    # Create the events data frame
    rows = []
    for e in gh_repo_obj.get_events():
        if e.type in issue_event_types or e.type in pr_event_types:
            event_id = e.id
            created_at = e.created_at
            event_contributor_id = e.actor.id
            event_contributor = e.actor.login
            event_type = e.type
            event_action = e.payload["action"]
            if event_type in issue_event_types:
                issue_or_pr_id = e.payload["issue"]["number"]
            else:
                issue_or_pr_id = e.payload["pull_request"]["number"]
            rows.append(
                [
                    event_id,
                    created_at,
                    event_contributor_id,
                    event_contributor,
                    event_type,
                    event_action,
                    issue_or_pr_id,
                ]
            )

    # Add column names for events data frame
    column_name = [
        "id",
        "created_at",
        "contributor_id",
        "contributor_name",
        "type",
        "action",
        "issue_or_pr_id",
    ]

    # Add other required colums
    events_df = pd.DataFrame(data=rows, columns=column_name)
    events_df["org"] = org
    events_df["repo"] = repo
    events_df["sig"] = sig
    events_df["internal_contributor"] = events_df["contributor_name"].apply(
        lambda x: x in internal
    )

    return events_df

# %%
events_df = get_events_df(
    sig="sig-data-science", org="os-climate", repo="aicoe-osc-demo"
)
events_df.head()
# Out:
#             id          created_at  contributor_id contributor_name  \
# 0  21404226591 2022-04-21 19:04:14        90428947       HeatherAck
# 1  21401943596 2022-04-21 16:38:12        82595185     JeremyGohBNP
# 2  21401915177 2022-04-21 16:36:28         8916126       Shreyanand
# 3  21401869003 2022-04-21 16:33:44        82595185     JeremyGohBNP
# 4  21401696347 2022-04-21 16:24:09         8916126       Shreyanand
#
#                 type   action  issue_or_pr_id         org            repo  \
# 0  IssueCommentEvent  created             150  os-climate  aicoe-osc-demo
# 1  IssueCommentEvent  created             150  os-climate  aicoe-osc-demo
# 2  IssueCommentEvent  created             150  os-climate  aicoe-osc-demo
# 3  IssueCommentEvent  created             150  os-climate  aicoe-osc-demo
# 4  IssueCommentEvent  created             150  os-climate  aicoe-osc-demo
#
#                 sig  internal_contributor
# 0  sig-data-science                 False
# 1  sig-data-science                 False
# 2  sig-data-science                  True
# 3  sig-data-science                 False
# 4  sig-data-science                  True

# %%
# read in and process events dfs for all repos
# then upload the processed df to s3 as a parquet file
for sig in sigs_file["sigs"]:
    for sp in sig["subprojects"]:
        for owners_slug in sp["owners"]:
            # parse org, repo names
            org, repo = get_org_repo_from_owners_slug(owners_slug)

            # create events df for org, repo
            events_df = get_events_df(sig=sig["dir"], org=org, repo=repo)

            # upload to bucket
            s3c.upload_df_to_s3(
                df=events_df,
                s3_prefix="open-services-group/metrics/github/events",
                s3_key=f"{org}-{repo}.parquet",
            )

# %% [markdown]
# ## Create Trino Tables
#
# Now that we have the processed data frames stored as parquet files in s3, we can generate [Trino](https://trino.io/) tables from it so that interactive dashboards can be implemented in [Superset](https://superset.apache.org/). We will be connecting to the [Operate First Trino](https://trino.operate-first.cloud/).

# %%
# Map the datatype columns of df to suitable datatype supported in Trino/Superset
_p2smap = {
    "object": "varchar",
    "int64": "bigint",
    "float64": "double",
    "datetime64[ns]": "timestamp",
    "bool": "boolean",
}


def pandas_type_to_sql(pt):
    st = _p2smap.get(pt)
    if st is not None:
        return st
    raise ValueError("unexpected pandas column type '{pt}'".format(pt=pt))


# Generate the Trino table schema
def generate_table_schema_pairs(df):
    ptypes = [str(e) for e in df.dtypes.to_list()]
    stypes = [pandas_type_to_sql(e) for e in ptypes]
    pz = list(zip(df.columns.to_list(), stypes))
    return ",\n".join(["    {n} {t}".format(n=e[0], t=e[1]) for e in pz])

# %%
# Create a Trino client
conn = trino.dbapi.connect(
    auth=trino.auth.BasicAuthentication(
        os.environ["TRINO_USER"], os.environ["TRINO_PASSWD"]
    ),
    host=os.environ["TRINO_HOST"],
    port=int(os.environ["TRINO_PORT"]),
    http_scheme="https",
    verify=True,
)
cur = conn.cursor()

# %%
# Check if Trino connection was successful
cur.execute("show catalogs")
cur.fetchall()[1]
# Out:
# ['data_science_general']

# %%
def create_table_from_df(df, table_name, s3_prefix):
    # Create the table with data populated from parquet file
    schema = generate_table_schema_pairs(df)

    tabledef = """create table if not exists data_science_general.default.{table_name}(
    {schema}
    ) with (
        format = 'parquet',
        external_location = 's3a://{s3_bucket}/{s3_prefix}'
    )""".format(
        table_name=table_name,
        schema=schema,
        s3_prefix=s3_prefix,
        s3_bucket=os.environ["S3_BUCKET"],
    )

    cur.execute(tabledef)
    return cur.fetchall()

# %%
create_table_from_df(
    issue_df, table_name="issues", s3_prefix="open-services-group/metrics/github/issues"
)
# Out:
# [[True]]

# %%
create_table_from_df(
    pr_df, table_name="prs", s3_prefix="open-services-group/metrics/github/prs"
)
# Out:
# [[True]]

# %%
create_table_from_df(
    events_df,
    table_name="events",
    s3_prefix="open-services-group/metrics/github/events",
)
# Out:
# [[True]]

# %% [markdown]
# ## Conclusion
#
# In this notebook we:
#
# - Fetched GitHub Issue/PR data for a specified org/repo using the MI `srcopsmetrics` module
# - Pre-processed the raw data into data frames with relevant columns
# - Uploaded the processed data frames as parquet files to an S3 bucket
# - Created suitable tables for the parquet files generated in Trino
#
# We can now further explore the GitHub data obtained for different repos/orgs and create interactive visualization dashboards in [Superset](https://superset.operate-first.cloud/).
